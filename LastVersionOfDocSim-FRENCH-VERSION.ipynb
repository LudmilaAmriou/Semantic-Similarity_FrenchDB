# %%
#importing required libraries
from gensim import corpora #pip install gensim ou pip install -U gensim
from collections import defaultdict
from gensim import similarities
from gensim import models
import json #pip install json
import re
import string
from spacy.lang.fr.stop_words import STOP_WORDS as fr_stop #pip install spacy / try pip install stop-words
import mysql.connector #pip install mysql-connector-python-rf

# %%
#reading json file
def load_data(file):
    with open (file, "r", encoding="utf-8") as f:
        data = json.load(f) 
    return (data)

# %%
#writing json file
def write_data(file, data):
    with open (file, "w", encoding="utf-8") as f:
        json.dump(data, f, indent=4)

# %%
def database(): #Read Database
    db=mysql.connector.connect(host='192.185.4.44',
                                           database='veillise_test2',
                                           user='veillise_veille2',
                                           password='@@@@@@@@@@@@@@')
    if db.is_connected():
            db_Info = db.get_server_info()
            print("Connected to MySQL Server version ", db_Info)
            cursor = db.cursor()
            cursor.execute("select database();")
            record = cursor.fetchone()
            print("You're connected to database: ", record)
    

    mycursor=db.cursor()
    query = "select id, titre, article, group_nb,lang from articles where lang='French' AND (group_nb = \"\" OR group_nb IS NULL) AND (created_at > DATE_ADD(NOW(), INTERVAL -36 HOUR));"

    cursor.execute(query)
    result = cursor.fetchall()
    if cursor.rowcount != 0 :
        print("No. of articles not analyzed ", cursor.rowcount)
    data = []
    for row in result:
        article = {}
        article["id"] = row[0]
        article["titre"]=row[1]
        article["lang"]=row[4]
        article["group_nb"]=row[3]
        article["article"]=row[2]
        data.append(article)
        
    print(len(data))
    return data

# %%
regex = re.compile(r'<[^>]+>')
pattern = r'[' + string.punctuation + ']'
def Clean_Data(txt):
    txt = txt.lower() #Lower text
    txt = re.sub(regex,'', txt) #Remove Html syntaxe
    txt = re.sub(r'http\S+', '', txt) #Remove URLs
    txt = re.sub(pattern,'', txt)
    return txt

# %%
def Cleaned_data(data): #List of List
    for i in range(len(data)):
        (data[i])["titre"] = Clean_Data((data[i])["titre"])
        (data[i])["article"] =  Clean_Data((data[i])["titre"]) + Clean_Data((data[i])["article"])
        
    return data #List of List

# %%
#Treat data 
def Treat_Data(data,string): #List of List 
    #Creating a list of stopwords
    #Removing stopwords ( Depends on BD too )
    stp = ["finalement", "autres", "h", "été", "est-ce", "qu’on", "vraiment" ,"c’est" ,"fera","tags","Tags"]
    stoplist= list(fr_stop)+ stp
    txts = [[word for word in document[string].lower().split() if word not in stoplist]for document in data]
    #Calculating frequency of each word 
    frequency = defaultdict(int)
    for text in txts:
        for token in text:
            frequency[token] += 1
    #Removing words that appear only once
    txts = [[token for token in text if frequency[token] > 1]for text in txts]
    #Creating a dictionary
    gensim_dictionary = corpora.Dictionary(txts)
    #Vectorizing the corpus
    gensim_corpus = [gensim_dictionary.doc2bow(text) for text in txts]
    return gensim_corpus,gensim_dictionary

# %%
def LSI(gensim_corpus,gensim_dictionary,numtopics): #creating LSI model
    lsi = models.LsiModel(gensim_corpus, id2word=gensim_dictionary, num_topics=numtopics)
    return lsi

# %%
'''-----Treating the query-------
    Query is the document that will be compared to 
    Doc is an article '''
def Treat_Query(doc):
    #Creating bow vector
    vec_bow = gensim_dictionary.doc2bow(doc.lower().split())
    #Converting the query to LSI space
    vec_lsi = lsi[vec_bow]  
    return vec_lsi

# %%
def Similarity(vec_lsi,gensim_corpus,lsi): #Testing similarity
    index = similarities.MatrixSimilarity(lsi[gensim_corpus])  
    simil = index[vec_lsi]  
    simil=sorted(list(enumerate(simil)),key=lambda item: -item[1])
    return simil

# %%
def Match_Sim(data,simil,nbsim,acc): #Match similar articles with a special id
    for doc_position, doc_score in simil:
        if doc_score>acc:
            (data[doc_position])["group_nb"] = nbsim 
    return data

# %%
data=database() #Read DataBase
write_data("./DataFINAL.json",data)
nbsim = 0 #id same articles
docs = load_data("./DataFINAL.json") 
docs = Cleaned_data(docs)
gensim_corpus,gensim_dictionary = Treat_Data(docs,"titre")
lsi = LSI(gensim_corpus,gensim_dictionary,3)
for i in range(len(docs)):
    if (docs[i])["group_nb"] == 0: 
        vec_lsi = Treat_Query((docs[i])["titre"])
        simil = Similarity(vec_lsi,gensim_corpus,lsi)
        if simil[i][1]==0.0:
            docs[i]["group_nb"]="NULL"
        else:
            nbsim += 1
            docs = Match_Sim(docs,simil,nbsim,0.99)
# Out:
# Connected to MySQL Server version  5.7.23-23
# You're connected to database:  ('veillise_test2',)
# No. of articles not analyzed  264
# 264

# %%
score = [] #Just to test the algorithm
for i in range(len(docs)):
    score.append([docs[i]['group_nb'],docs[i]['id']])
print(score)
# Out:
# [[1, 339234], [2, 339233], ['NULL', 339231], [3, 339232], [4, 339230], [22, 339228], [5, 339229], [5, 339226], [6, 339227], [38, 339224], [12, 339225], [22, 339223], [7, 339222], [7, 339221], [1, 339219], [5, 339218], ['NULL', 339209], ['NULL', 339210], ['NULL', 339211], ['NULL', 339212], ['NULL', 339213], ['NULL', 339214], ['NULL', 339215], [22, 339216], [22, 339207], [7, 339206], [8, 339194], [22, 339195], [7, 339365], [5, 339366], [22, 339364], [5, 339359], [22, 339356], [2, 339357], [9, 339358], [22, 339355], [22, 339352], [4, 339353], [10, 339351], [9, 339348], [11, 339347], [12, 339343], [22, 339341], [22, 339342], [5, 339339], [13, 339337], [14, 339336], [5, 339334], [11, 339335], [15, 339317], [22, 339318], [4, 339321], [10, 339333], [5, 339332], [24, 339331], [11, 339327], [13, 339326], [7, 339325], [22, 339323], [16, 339309], [22, 339310], [38, 339311], [17, 339312], [18, 339313], [8, 339314], [19, 339315], [20, 339316], [21, 339303], [22, 339304], [22, 339305], ['NULL', 339306], ['NULL', 339307], [22, 339308], ['NULL', 339298], [22, 339300], [3, 339301], [10, 339302], [13, 339299], [23, 339297], [24, 339296], [7, 339289], [6, 339290], [3, 339280], [5, 339275], [22, 339276], [25, 339270], [24, 339271], [7, 339272], [26, 339273], [22, 339274], [36, 339535], ['NULL', 339534], [5, 339533], [8, 339532], [22, 339531], [27, 339527], [10, 339525], [22, 339526], [22, 339524], [22, 339521], [7, 339522], [28, 339523], [5, 339515], [22, 339516], [22, 339517], [29, 339518], [22, 339519], [22, 339520], [30, 339508], [22, 339509], [15, 339510], [10, 339511], [10, 339512], [10, 339513], [22, 339514], [15, 339507], [5, 339505], [31, 339506], ['NULL', 339502], [4, 339503], [28, 339504], [22, 339500], [2, 339501], [36, 339498], [5, 339499], [15, 339496], [22, 339497], [7, 339495], [22, 339492], [6, 339493], [10, 339494], [32, 339484], [30, 339485], [22, 339486], [22, 339487], [11, 339480], [22, 339481], [5, 339482], [22, 339483], [11, 339479], [4, 339478], [33, 339477], [10, 339475], [22, 339476], [7, 339474], [18, 339473], [10, 339470], [5, 339471], [22, 339472], [34, 339469], [3, 339465], ['NULL', 339466], [13, 339467], [22, 339468], [7, 339464], [7, 339462], [8, 339463], [22, 339460], [7, 339461], [11, 339458], [38, 339459], ['NULL', 339456], [11, 339457], [10, 339455], [22, 339450], [5, 339451], [10, 339452], [10, 339453], [8, 339454], [21, 339448], [22, 339449], [5, 339447], [30, 339441], [10, 339442], [5, 339443], [32, 339444], [5, 339446], [10, 339445], [24, 339440], [35, 339436], [30, 339437], [22, 339438], [5, 339439], [13, 339431], [27, 339432], [32, 339433], [38, 339434], [7, 339435], [12, 339428], [22, 339429], [9, 339430], [36, 339427], [32, 339417], [10, 339418], [5, 339419], [11, 339420], [5, 339421], [5, 339422], [5, 339423], [5, 339424], [3, 339425], [5, 339426], [38, 339416], [7, 339412], [10, 339413], [37, 339411], [10, 339410], [22, 339406], [26, 339409], [4, 339269], ['NULL', 339235], [36, 339236], [22, 339237], [5, 339238], [2, 339239], [22, 339240], [22, 339241], [32, 339242], [24, 339243], [22, 339244], [38, 339245], [3, 339246], [13, 339247], [7, 339248], [5, 339249], [22, 339250], [5, 339251], [5, 339252], [5, 339253], [22, 339254], [36, 339255], [11, 339256], [22, 339257], [22, 339258], [26, 339259], [5, 339260], [12, 339261], [32, 339262], [9, 339263], [5, 339264], [28, 339265], [22, 339266], [22, 339267], [5, 339268], [39, 339403], [39, 339404], [36, 339402], [17, 339401], [10, 339400], [22, 339399], [13, 339397], [5, 339394], [5, 339396], [7, 339389], [11, 339390], ['NULL', 339382], [35, 339383], [34, 339384], [7, 339385], [10, 339388], [32, 339374], [7, 339375], [22, 339376], [10, 339377]]

# %%
for i in range(len(docs)):
    print((docs[i])['titre'] , ',', (docs[i])['group_nb'])
    print()
# Out:
# conflit en ukraine quatre régions vont être intégrées à la russie
#  , 1
#
#
# en jouant les médiateurs dans le conflit en ukraine larabie saoudite cherche à revenir au devant de la scène
#  , 2
#
#
# laura dantan retrouvée
#  , NULL
#
#
# energie atomique lalgérie dévoile sa stratégie
#  , 3
#
#
# l’ua l’oci et la ligue arabe soutiennent la candidature de l’algérie au conseil de sécurité la symphonie algérienne séduit
#  , 4
#
#
# tizi ouzou huawei met en place une académie dexcellence
#  , 22
#
#
# des festivités du 1er novembre bien particulières 30000 logements seront distribués
#  , 5
#
#
# disponibilité du médicament aoun rencontre les pharmaciens dofficine
#  , 5
#
#
# révision et allègement du programme scolaire les propositions des spécialistes
#  , 6
#
#
# journée mondiale du tourisme célébration a minima à béjaïa
#  , 38
#
#
# concrétisation du partenariat amorcé entre les deux pays fin août benabderrahmane et borne à loeuvre
#  , 12
#
#
# tourisme comment attirer les étrangers
#  , 22
#
#
# officiellement invité au sommet arabe dalger que fera mohammed vi
#  , 7
#
#
# sommet arabe dalger un pari pour la paix
#  , 7
#
#
# 15000 tonnes de tubes en spirale exportées vers langola tosyali enchaîne les contrats
#  , 1
#
# match amical international algérie 2nigéria 1 nouvelle victoire nouveaux espoirs  , 5
#
#  , NULL
#
#  , NULL
#
#  , NULL
#
#  , NULL
#
#  , NULL
#
#  , NULL
#
#  , NULL
#
#  foot amical  lalgérie domine le nigeria 21  , 22
#
#
# les buts ont été inscrits par mahrez et atal les verts s’imposent face au nigeria 21 vidéo
#  , 22
#
# ahmed mizab  «l’algérie sera la capitale de tous les pays arabes lors du sommet arabe» , 7
#
# omra 2022 «les billets d’avion ne sont pas encore disponibles» regrette le voyagiste mohamed larouci , 8
#
# rencontre aounsnapo le ministre dénonce les cas de monopole dans l’importation et la distribution des produits pharmaceutiques , 22
#
# sommet arabe d’alger  le président tebboune invite officiellement le roi du maroc mohammed vi , 7
#
# autoroute de béjaïa  ces obstacles qui freinent le projet , 5
#
#  zreb le système pénitentiaire basé sur le respect des droits de lhomme  , 22
#
#
# le directeur général de la compagnie nationale l’annonce «air algérie ouvrira de nouvelles dessertes»
#  , 5
#
#  le 12e salon international des énergies renouvelables en octobre à oran  , 22
#
#  conférence des plénipotentiaires de luit bibitriki à bucarest  , 2
#
#  laccès à linternet haut et très haut débit priorité du gouvernement  , 9
#
#  can2023 u23algérierd congo il faut quon soit prêts à tous les niveaux  , 22
#
#  les relations historiques profondes algéroindonésiennes évoquées à alger  , 22
#
#  le président tebboune reçoit lambassadeur du ghana  , 4
#
# fuites sur les gazoducs nord stream 1 et 2  les prix du gaz flambent en europe , 10
#
#  la promotion de lindustrie pharmaceutique cheval de bataille du gouvernement  , 9
#
#  espagne le parlement des baléares condamne le massacre de nadormelilla  , 11
#
#
# il lui a rendu une visite dadieu au terme de sa mission en algérie tebboune reçoit l’ambassadeur du ghana
#  , 12
#
#  stade de douéra belaribi instruit de parachever les travaux dans les délais impartis  , 22
#
#  une commission chargée du suivi de linnovation et des incubateurs universitaires  , 22
#
#  le ministère de la culture et des arts prend part à la 21e édition du sitev  , 5
#
#  la fête du mawlidennabaoui echarif célébrée samedi 8 octobre  , 13
#
#  ligue 1 6e journée  le rca pour enchaîner lusb en quête de rachat  , 14
#
# caritas algérie met fin à ses activités , 5
#
#  energie plusieurs actions engagées pour réussir la transition énergétique  , 11
#
#  larmée sahraouie mène de nouvelles attaques contre les forces doccupation marocaines à mahbes elbakari et houza  , 15
#
#  football statistiques les verts se détachent des supers eagles pour leur 23e face à face  , 22
#
#  onuconseil de sécurité consultations sur la question palestinienne  , 4
#
# rencontre avec taha merghoub brillant chercheur algérien aux usa , 10
#
# dérapages rendement en baisse  belaili inquiète belmadi , 5
#
#  santé lancement dun plan national stratégique contre la rage 20232027  , 24
#
#
#             match amical  l’algérie bat une nouvelle fois le nigéria 2 à 1 vidéo     , 11
#
#  footballsélection algérienne  les verts tout proches d’un vieux record national  , 13
#
#  marché pétrolier lopep célèbre le 6éme anniversaire de laccord historique dalger  , 7
#
#
# il s’y est rendu hier soir pour inspecter létat davancement des travaux visite surprise de belaribi au stade de douéra
#  , 22
#
# activité portuaire de djen djen «une hausse de 30 chaque année depuis 2017» , 16
#
# 28e commémoration de l’assassinat de hasni une pièce de théâtre en hommage au rossignol , 22
#
# constantine  10e festival du malouf vif succès de la soirée inaugurale avec salim fergani , 38
#
# statut de l’artiste enfin le bout du tunnel  , 17
#
# crise au liban un nouveau président pour sortir de l’impasse politique  , 18
#
# libye la situation sécuritaire au cœur dune réunion du conseil présidentiel , 8
#
# burkina faso au moins dix soldats tués dans lattaque de camions de ravitaillement , 19
#
# sahara occidental larrêt de la cour africaine une preuve de léchec de la politique marocaine , 20
#
# relizane campagne de sensibilisation du secteur de la formation professionnelle , 21
#
# tourisme plus de 6 millions destivants ont visité le littoral témouchentois , 22
#
# mostaganem ouverture de la 2e édition du salon international de l’agriculture , 22
#
# aïnbeïda arrestation de trois dealers , NULL
#
# chechar khenchela plus de 400 lots de terrains à bâtir attribués , NULL
#
# agriculture à constantine les pluies de lespoir , 22
#
# hb chelghoumlaïd séparation consommée entre le hilal et rouabah , NULL
#
# mc alger arrivée différée de benzarti , 22
#
# il doit rentrer aujourd’hui à brest pour rompre son contrat belaïli le gâchis du siècle  , 3
#
#  impact du développement du gaz de schiste sur les ressources en eau , 10
#
# usf constantine interrégions groupe est un nouveau promu aux dents longues , 13
#
# boxe  alors que les membres du bf réclament le départ du président de la fab le mjs enquête ferhatfazil dans de beaux draps  , 23
#
# mourad ferguene exchampion dafrique  «lalgérien est fait pour la boxe» , 24
#
# sommet arabe d’alger  le président tebboune invite officiellement le roi du maroc , 7
#
# peuton encore vivre sereinement en france en tant que musulman  , 6
#
#  festival national du malouf de constantine  une ambiance apaisante lors de la 2ème soirée  , 3
#
#  foot match amical algérienigéria 21  garder l’esprit de la gagne  , 5
#
#  foot amical algérienigéria 21  les verts renversent les supers eagles  , 22
#
#  hémopathies  appel au renforcement des centres des maladies du sang  , 25
#
#  signature dune conventioncadre entre le groupe acs et algerac  , 24
#
#  le sg de lunpa insiste sur limpératif de protéger le foncier agricole  , 7
#
#  sonelgaz le problème de recouvrement des créances entrave la réalisation des investissements programmés  , 26
#
#  apn réunion de coordination sous la présidence de boughali  , 22
#
#  hand coupe dafrique des nations dames 2022 tirage  lalgérie hérite du groupe a avec langola  , 36
#
#  belani se félicite des bonnes conditions du déroulement du concours daccès aux grades dattachés et secrétaire des ae  , NULL
#
#  foot match amical sélection algérienne a’  déclarations des joueurs avant d’affronter le soudan  , 5
#
#  entmv une consultation internationale pour lacquisition dun nouveau système de réservation électronique  , 8
#
#  le ministre du tourisme et de lartisanat sentretient avec son homologue tunisien  , 22
#
# huile table  avec l’usine cevital l’algérie va changer de statut , 27
#
#
#             sonatrach  vers la révision du prix du gaz fourni à l’espagne     , 10
#
#  ouverture jeudi à alger du 21e salon international du tourisme et des voyages  , 22
#
#
#             algérienigeria 21  les verts reprennent confiance et affichent leurs ambitions     , 22
#
#
# un colloque international lui est consacré saint augustin de retour à souk ahras
#  , 22
#
#
# 14e fibda à lesplanade de riadh el feth le japon invité dhonneur
#  , 7
#
#
# organisé à londres festival algérien des arts et de la culture «dz fest»
#  , 28
#
#
# djamel belmadi «cest dans la difficulté quon progresse»
#  , 5
#
#
# les verts avec le nouveau maillot
#  , 22
#
#
# équipe nationale a benbot et khelif forfaits contre le soudan
#  , 22
#
#
# ligue 2  2e journée entre rachat et confirmation
#  , 29
#
#
# stade de annaba pose du tapis artificiel en fibres synthétiques
#  , 22
#
#
# manchester united maguire cest désastreux
#  , 22
#
#
# le koweït vote aujourdhui 313 candidats aux élections législatives
#  , 30
#
#
# le niger suspend le transit des produits pétroliers vers le mali tensions accrues au sahel
#  , 22
#
#
# ciblant les forces doccupation marocaines larmée sahraouie mène de nouvelles attaques à mahbes elbakari et houza
#  , 15
#
#
# fuite de gaz dans les nord stream 1 et 2 moscou juge «stupides» les soupçons occidentaux
#  , 10
#
#
# béjaïa 60 cantines scolaires à larrêt
#  , 10
#
#
# explosion du prix du gaz à linternational une aubaine pour les cimentiers
#  , 10
#
#
# fin du stage des verts du bon et du moins bon
#  , 22
#
#
# sous les balles des forces doccupation sionistes à jénine quatre palestiniens tombent en martyrs
#  , 15
#
#
# référendums au donbass les autorités pro russes revendiquent la victoire
#  , 5
#
#
# duel lula  bolsonaro au brésil les principaux candidats à la présidentielle
#  , 31
#
#
# revalorisation des salaires des enseignants ce quen attendent les syndicats
#  , NULL
#
#
# lue finance un programme dun million deuros pour la cour des comptes comment bénéficier de lexpertise étrangère
#  , 4
#
#
# développement du partenariat publicprivé en phase de concrétisation
#  , 28
#
#
# salon national de lhabitat de limmobilier et du décor penser une maison intelligente
#  , 22
#
#
# oran trois ateliers illégaux démantelés
#  , 2
#
#
# loi régissant les relations entre le parlement et le gouvernement des «lignes rouges» tracées
#  , 36
#
#
# tizi ouzou 70 milliards pour le parc immobilier
#  , 5
#
#
# saïda le wali active son autorité dans deux apc
#  , 15
#
#
# le mois doctobre sera chargé en activités politiques et diplomatiques alger retrouve son aura
#  , 22
#
#
# lopep fête le 6ème anniversaire de laccord historique dalger un succès diplomatique éclatant
#  , 7
#
#
# le ministre russe de lagriculture la affirmé hier «nos entreprises sont prêtes à investir en algérie»
#  , 22
#
#
# la république populaire de chine a 73 ans un géant qui voit grand
#  , 6
#
#
# au terme dâpres négociations menées avec lespagne et litalie sonatrach relève les prix du gaz
#  , 10
#
# spéculation une importante quantité de l’huile de table saisie à tébess , 32
#
# douanes saisie de plus de 16000 comprimés hallucinogènes , 30
#
# accidents de la circulation 139 interventions effectuées par la protection civile , 22
#
# affaires religieuses mawlid el nabawi sera célébré le 08 octobre prochain , 22
#
# afin de faire connaître l’étendue du patrimoine culturel le ministère de la culture présent en force au sitev  , 11
#
# covid19 huit nouvelles infections enregistrées , 22
#
# système pénitentiaire en algérie zreb évoque le respect des droits de l’homme et la préservation de la dignité des détenus , 5
#
# en vue d’éradiquer la rage d’ici 2030 lancement d’un plan national stratégique , 22
#
# théâtre musique symphonique inchad bd…  5 festivals au programme du mois d’octobre , 11
#
# sonelgaz  «les créances ont atteint 161 milliards da» selon mourad adjal , 4
#
# dilmi  «le foncier agricole est une ligne rouge à ne pas franchir» , 33
#
# sonatarch une augmentation de la consommation de gaz estimé entre 4 à 5  par an , 10
#
# energies renouvelables “«mise en place d’une capacité de 15000 mwe à l’horizon 2035» , 22
#
# l’opep célèbre le 6éme anniversaire de l’accord historique d’alger , 7
#
# koli  «les producteurs locaux ont gagné le pari de faire de la rentrée scolaire une réussite» , 18
#
# hakkar  «ces accords ouvrent des horizons de partenariat solide avec l’italie et l’espagne» , 10
#
# apn air algérie augmentera le nombre de ses vols à partir d’octobre prochain , 5
#
# salon international des énergies renouvelables la 12 ème édition du 24 au 26 octobre à oran , 22
#
# boukhalfa laala  «il y a une volonté politique mais le problème réside dans l’application des directives» , 34
#
# création d’une commission nationale de coordination et de suivi de l’innovation , 3
#
# boumerdès  près de 300 familles relogées , NULL
#
# mostaganem  le wali insiste sur l’investissement dans l’élevage des vaches laitières , 13
#
# 1ere édition du ccus à oran  pour une empreinte carbone nulle à l’horizon 2030 , 22
#
# hossam zaki salue les efforts déployés par toutes les institutions étatiques algériennes pour la réussite du sommet arabe , 7
#
# suleiman abdel rahim dg de l’asbu«le sommet arabe d’alger connaît un niveau de préparation jamais atteint durant ces 20 dernières années» , 7
#
# les relations historiques profondes entre les deux pays évoquées , 8
#
# réunion du gouvernement quatre secteurs à l’ordre du jour , 22
#
# anp mise en échec de l’introduction de plus 14 quintaux de kif traité via les frontières avec le maroc , 7
#
#
# equipe d’algérie  belmadi veut 3 matchs amicaux en novembre , 11
#
#
# affaire brest  belmadi lance un conseil à belaïli , 38
#
#
# turquie  feghouli en litige avec galatasaray , NULL
#
#
# equipe d’algérie  quand belmadi compare bennacer à iniesta et modric , 11
#
#
# gaz  sonatrach signe de nouveaux accords avec l’italien enel , 10
#
#
# taux de change banque et marché noir  l’euro décroît ce 28 septembre , 22
#
#
# météo algérie  alerte pluies et orages sur 6 wilayas ce 28 septembre , 5
#
#
# france  quand un algérien résiste à son expulsion à marseille , 10
#
#
# hausse prix du gaz livré à l’espagne  ce qu’a dit le pdg de sonatach , 10
#
#
# coût de la vie  quel pouvoir d’achat pour les algériens en 2022  , 8
#
#
# crime crapuleux à relizane  un jeune égorgé dans une forêt , 21
#
#
# le lycée national des arts « ali maâchi » ouvre ses portes à alger , 22
#
#
# logement aadl en algérie  vers une nouvelle distribution , 5
#
#
# trafic de drogue au jardin d’essai  2 hommes et 1 femme écroués , 30
#
#
# prix articles scolaires  le ministère du commerce explique la flambée , 10
#
#
# covid19 en algérie  légère hausse du nombre de cas ce 28 septembre , 5
#
#
# les prix de l’huile d’olive flambent en algérie , 32
#
#
# crise algérie – espagne  quels sont les secteurs impactés  , 5
#
#
# france  un couple algérien se déchire pour un titre de séjour , 10
#
#
# anniversaire de la mort de cheb hasni  un « big » événement au menu , 24
#
# l’algérien venu de paris à pied fait une nouvelle apparition à l’approche d’alger , 35
#
# l’espagne lance un appel à l’algérie après les retombées de la crise sur son économie , 30
#
#
# chasse aux « parkingueurs »  la police fait une descente à alger , 22
#
#
# 4 secteurs au menu de la réunion du gouvernement ce 28 septembre , 5
#
# record des algériens belloumi et madjer  mahrez s’approche doucement mais surement , 13
#
# maillot d’entraînement adidas  des marocains accusent l’algérie de dérober leurs symboles , 27
#
# équipe d’algérie  belmadi évoque 2 matchs internationaux pour novembre , 32
#
# « bizarre que l’algérie ne soit pas qualifiée au mondial » estime mustapha alagha vidéo , 38
#
# invité au sommet arabe d’alger le roi du maroc mohammed vi viendratil  , 7
#
# l’algérienne amira riaa s’explique sur le raisons de son déménagement à dubaï , 12
#
# un supporter attaque avec les verts contre le nigeria  vidéo prise du meilleur angle de vue , 22
#
# télégramme  l’algérien « belaïli a massacré son appartement à brest et a disparu à paris » , 9
#
# l’algérienne dalia chih rend hommage à idir dans un concert à paris , 36
#
# algérie – espagne  du nouveau pour le gaz , 32
#
# un algérien de 70 ans termine le marathon de berlin dans le même temps que le ballon d’or kaka , 10
#
# foot  avec un belaili la tête ailleurs et un atal en superforme l’algérie domine le nigeria en amical , 5
#
# algérie  une mesure avantageant l’italie au détriment de l’espagne , 11
#
# automobile en algérie  voici le nombre de voitures converties au gpl en 2022 , 5
#
# immobilier algérie  du nouveau pour ce qui est des logements aadl , 5
#
# aadl algérie  une large opération de distribution à cette date , 5
#
# algérie  ooredoo met en vente ses tours télécoms , 5
#
# ouedkniss auto  les offres de vente de voitures de ce 28 septembre 2022 , 3
#
# algérie  visite surprise du ministre de l’habitat en pleine nuit au stade de douera vidéo , 5
#
# l’algérie veut faire connaître sa production agricole vidéo , 38
#
#  sommet arabe stéphane dujarric confirme la participation du sg de lonu  , 7
#
#  sonatrach  accord avec six partenaires sur la révision des prix du gaz exporté  , 10
#
#  algérierussie intensifier les investissements communs et transférer la technologie  , 37
#
# gaz algérien  les prix réajustés pour l’italie et l’espagne , 10
#
#
# 21ème édition du salon international du tourisme et des voyages sitev benabderrahmane donnera le coup de starter
#  , 22
#
#  prix du président de la république du journaliste professionnel les membres du jury installés  , 26
#
# politique générale du gouvernement  comment relancer l’économie nationale  via le code d’investissement et la bourse d’alger  , 4
#
#
# trêve au yémen alalimi et l’envoyé spécial de l’onu discutent du renouvellement
#  , NULL
#
#
# il annonce une récolte record en russie de 150 millions de tonnes en 2022 poutine critique des exportations ukrainiennes réservées à l’ue
#  , 36
#
#
# à la tribune des nations unies le premier ministre malien solde les comptes
#  , 22
#
#
# la victoire de lextrême droite plonge le pays dans une ère dincertitudes une partition italienne
#  , 5
#
#
# burkina au moins une «dizaine de morts» dans une attaque terroriste
#  , 2
#
#
# stade brestois belaïli cest déjà fini
#  , 22
#
#
# js kabylie amrani met la machine en branle
#  , 22
#
#
# activités physiques et sportives le développement et les performances mis en relief
#  , 32
#
#
# coupe dalgérie 20222023 la compétition fait son retour
#  , 24
#
#
# championnat dafrique de triathlon lalgérie décroche deux médailles
#  , 22
#
#
# real madrid perez pourra se faire plaisir au mercato
#  , 38
#
#
# festival national du théâtre comique à médéa hommage à sirat boumediene
#  , 3
#
#
# commémoration du décès de cheb hasni la pièce «hasni chante ce jeudi» bientôt présentée
#  , 13
#
#
# institut français dalger spectacle de danse contemporaine
#  , 7
#
#
# il se tiendra le 4 octobre un colloque international sur le théâtre amazigh
#  , 5
#
#
# conférence à tlemcen promotion du tourisme et la protection du legs culturel
#  , 22
#
#
# radiothérapie stéréotaxique la nouvelle acquisition du chu dannaba
#  , 5
#
# algérie – nigéria  belle victoire pour les hommes de belmadi , 5
#
#
#             algérienigeria  un match amical à caractère officiel     , 5
#
# stade brestoisle match contre les parisiens pourrait précipiter le départ du dz de la bretagne  belaïli l’indigeste parisbrest , 22
#
# la sélection ne se porte pas bien à quelques semaines de la coupe du monde 2022  le doute grandit pour le qatar  , 36
#
# jo2024avant de débloquer l’enveloppe de 4 milliards pour les athlètes qualifiés  fédérations  les autorités prévoient un sacré coup de balai  , 11
#
# sur son refus du vaccin  irving  « j’ai renoncé a 100 et quelques millions en maintenant ma décision » , 22
#
# tennis  cet indice sur les intentions de nadal pour la fin de saison , 22
#
# tennis  quand djokovic recadre un journaliste sur nadal , 26
#
# le chant traditionnel authentique ravive la scène artistique  cirta retrouve son festival du malouf , 5
#
# projet de loi de l’artiste  plaidoyer pour la création de marchés de l’art , 12
#
# espagne  la guerre fiscale est lancée à un an des élections , 32
#
# italie  délicates tractations de meloni pour former son gouvernement , 9
#
# après la victoire de meloni en italie  vers un axe italiehongriepologne au sein de l’ue , 5
#
# organisation à londres du festival algérien des arts et de la culture «dz fest» , 28
#
# coup d’envoi dans la soirée de lundi à mostaganem de la 53e édition  le festival culturel national du théâtre amateur retrouve les planches , 22
#
# avec 105 millions d’estivants nationaux et étrangers et 200 milliards de da de chiffre d’affaires  le tourisme reprend des couleurs , 22
#
# finances locales et aménagement du territoire  quid des marges de manœuvre de la nouvelle approche  , 5
#
#  médias en temps de guerre le forum de la mémoire salue le rôle pionnier de feu mhamed yazid  , 39
#
#  le président du cnese examine avec les présidents de groupes parlementaires les moyens de coopération avec le parlement  , 39
#
#  le gouvernement examine un avantprojet de loi relatif à la protection du droit syndical  , 36
#
#  stratégie nationale de développement des statistiques un impératif pour être au diapason des changements nationaux et internationaux  , 17
#
#  gaz naturel sonatrach et enel signent des accords pour lajustement des prix  , 10
#
#  le premier ministre inaugurera jeudi le 21e sitev  , 22
#
#  etablissements publics de santé les équipes dinspection entament leurs visites  , 13
#
# la rage continue de tuer en algérie , 5
#
#  air algérie le nombre de vols atteindra 78 des niveaux davant covid19  , 5
#
#  sommet arabe émission dun timbreposte arabe unifié 2022  , 7
#
#  laast disposée à contribuer au développement national  , 11
#
#  arrivée à alger de la dépouille de la journaliste et moudjahida zineb el mili  , NULL
#
#  de bandung à lonu quand la question algérienne prenait une dimension internationale  , 35
#
#  ligue 2 amateur  confirmer les bons débuts pour certains se ressaisir pour dautres  , 34
#
#
# dans le cadre des préparatifs du sommet arabe dalger lamamra reçoit le sg adjoint de la ligue arabe
#  , 7
#
#  finance islamique la ba signe un contrat dassistance technique  , 10
#
#  la chine attache une grande importance au développement des relations avec lalgérie  , 32
#
#  lamamra reçoit le sg adjoint de la ligue arabe  , 7
#
#  mostaganem des solutions innovantes pour réduire les effets du changement climatique  , 22
#
# pourquoi l’espagne ne veutelle pas résoudre le problème du sahara occidental  , 10

# %%
d=mysql.connector.connect(host='192.185.4.44',
                                           database='veillise_test2',
                                           user='veillise_veille2',
                                           password='veille2@2020@')

mycursor = d.cursor()
query2 = "select id, titre, article, group_nb,lang from articles where lang='French' AND (created_at > DATE_ADD(NOW(), INTERVAL -36 HOUR));"
mycursor.execute(query2)
myresult = mycursor.fetchall()
for x in myresult:
    
    print(x[0], ':', x[1],'grp nb: ', x[3])
    print()
# Out:
# 339234 :
# Conflit en Ukraine Quatre régions vont être intégrées à la Russie
#  grp nb:  0
#
# 339233 :
# En jouant les médiateurs dans le conflit en Ukraine L'Arabie saoudite cherche à revenir au- devant de la scène
#  grp nb:  0
#
# 339231 :
# L'aura d'antan retrouvée
#  grp nb:  0
#
# 339232 :
# Energie atomique L'Algérie dévoile sa stratégie
#  grp nb:  0
#
# 339230 :
# L’UA, L’OCI et La ligue arabe soutiennent la candidature de l’Algérie au conseil de sécurité La symphonie algérienne séduit
#  grp nb:  0
#
# 339228 :
# Tizi Ouzou Huawei met en place une Académie d'excellence
#  grp nb:  0
#
# 339229 :
# Des festivités du 1er novembre bien particulières 30000 logements seront distribués
#  grp nb:  0
#
# 339226 :
# Disponibilité du médicament Aoun rencontre les pharmaciens d'officine
#  grp nb:  0
#
# 339227 :
# Révision et allègement du programme scolaire Les propositions des spécialistes
#  grp nb:  0
#
# 339224 :
# Journée mondiale du tourisme Célébration a minima à Béjaïa
#  grp nb:  0
#
# 339225 :
# Concrétisation du partenariat amorcé entre les deux pays fin août Benabderrahmane et Borne à l'oeuvre
#  grp nb:  0
#
# 339223 :
# Tourisme Comment attirer les étrangers?
#  grp nb:  0
#
# 339222 :
# Officiellement invité au Sommet arabe d'Alger Que fera Mohammed VI?
#  grp nb:  0
#
# 339221 :
# Sommet arabe d'Alger Un pari pour la paix
#  grp nb:  0
#
# 339219 :
# 15000 tonnes de tubes en spirale exportées vers l'Angola Tosyali enchaîne les contrats
#  grp nb:  0
#
# 339218 : Match amical international, Algérie 2-Nigéria 1 Nouvelle victoire, nouveaux espoirs ! grp nb:  0
#
# 339209 :  grp nb:  0
#
# 339210 :  grp nb:  0
#
# 339211 :  grp nb:  0
#
# 339212 :  grp nb:  0
#
# 339213 :  grp nb:  0
#
# 339214 :  grp nb:  0
#
# 339215 :  grp nb:  0
#
# 339216 :  Foot/ Amical : l'Algérie domine le Nigeria (2-1)  grp nb:  0
#
# 339207 :
# Les buts ont été inscrits par Mahrez et Atal Les Verts s’imposent face au Nigeria (2-1) (Vidéo)
#  grp nb:  0
#
# 339206 : Ahmed Mizab : «L’Algérie sera la capitale de tous les pays arabes lors du sommet arabe» grp nb:  0
#
# 339194 : Omra 2022: «Les billets d’avion ne sont pas encore disponibles», regrette le voyagiste Mohamed Larouci grp nb:  0
#
# 339195 : Rencontre Aoun-SNAPO: Le ministre dénonce les cas de monopole dans l’importation et la distribution des produits pharmaceutiques grp nb:  0
#
# 339365 : Sommet arabe d’Alger : le président Tebboune invite officiellement le roi du Maroc Mohammed VI grp nb:  0
#
# 339366 : Autoroute de Béjaïa : ces obstacles qui freinent le projet grp nb:  0
#
# 339364 :  Zreb: le système pénitentiaire basé sur le respect des droits de l'homme  grp nb:  0
#
# 339359 :
# Le directeur général de la Compagnie nationale l’annonce «Air Algérie ouvrira de nouvelles dessertes»
#  grp nb:  0
#
# 339356 :  Le 12e Salon international des énergies renouvelables en octobre à Oran  grp nb:  0
#
# 339357 :  Conférence des plénipotentiaires de l'UIT: Bibi-Triki à Bucarest  grp nb:  0
#
# 339358 :  L'accès à l'Internet haut et très haut débit, priorité du Gouvernement  grp nb:  0
#
# 339355 :  CAN-2023 (U23)/Algérie-RD Congo: "Il faut qu'on soit prêts à tous les niveaux"  grp nb:  0
#
# 339352 :  Les relations historiques profondes algéro-indonésiennes évoquées à Alger  grp nb:  0
#
# 339353 :  Le Président Tebboune reçoit l'ambassadeur du Ghana  grp nb:  0
#
# 339351 : Fuites sur les gazoducs Nord Stream 1 et 2 : les prix du gaz flambent en Europe grp nb:  0
#
# 339348 :  La promotion de l'industrie pharmaceutique cheval de bataille du gouvernement  grp nb:  0
#
# 339347 :  Espagne: le Parlement des Baléares condamne le massacre de Nador-Melilla  grp nb:  0
#
# 339343 :
# Il lui a rendu une visite d'adieu au terme de sa mission en Algérie Tebboune reçoit l’Ambassadeur du Ghana
#  grp nb:  0
#
# 339341 :  Stade de Douéra: Belaribi instruit de parachever les travaux dans les délais impartis  grp nb:  0
#
# 339342 :  Une commission chargée du suivi de l'innovation et des incubateurs universitaires  grp nb:  0
#
# 339339 :  Le ministère de la Culture et des Arts prend part à la 21e édition du SITEV  grp nb:  0
#
# 339337 :  La fête du Mawlid-Ennabaoui Echarif célébrée samedi 8 octobre  grp nb:  0
#
# 339336 :  Ligue 1 (6e journée) : le RCA pour enchaîner, l'USB en quête de rachat  grp nb:  0
#
# 339334 : Caritas Algérie met fin à ses activités grp nb:  0
#
# 339335 :  Energie: plusieurs actions engagées pour réussir la transition énergétique  grp nb:  0
#
# 339317 :  L'Armée sahraouie mène de nouvelles attaques contre les forces d'occupation marocaines à Mahbes, El-Bakari et Houza  grp nb:  0
#
# 339318 :  Football (statistiques): les Verts se détachent des "Supers Eagles" pour leur 23e face à face  grp nb:  0
#
# 339321 :  ONU/Conseil de sécurité: consultations sur la question palestinienne  grp nb:  0
#
# 339333 : Rencontre avec Taha Merghoub, brillant chercheur algérien aux USA grp nb:  0
#
# 339332 : Dérapages, rendement en baisse : Belaili inquiète Belmadi grp nb:  0
#
# 339331 :  Santé: lancement d'un Plan national stratégique contre la rage 2023-2027  grp nb:  0
#
# 339327 :
#             Match amical : L’Algérie bat une nouvelle fois le Nigéria 2 à 1 (Vidéo)     grp nb:  0
#
# 339326 :  Football/sélection algérienne : les Verts tout proches d’un vieux record national  grp nb:  0
#
# 339325 :  Marché pétrolier: l'Opep célèbre le 6éme anniversaire de l'Accord historique d'Alger  grp nb:  0
#
# 339323 :
# Il s’y est rendu, hier soir, pour inspecter l'état d'avancement des travaux Visite surprise de Belaribi au stade de Douéra
#  grp nb:  0
#
# 339309 : Activité portuaire de Djen Djen «Une hausse de 30% chaque année depuis 2017» grp nb:  0
#
# 339310 : 28e commémoration de l’assassinat de HasnI Une pièce de théâtre en hommage au rossignol grp nb:  0
#
# 339311 : CONSTANTINE : 10e FESTIVAL DU MALOUF Vif succès de la soirée inaugurale avec Salim Fergani grp nb:  0
#
# 339312 : Statut de l’artiste Enfin le bout du tunnel ? grp nb:  0
#
# 339313 : Crise au Liban Un nouveau président pour sortir de l’impasse politique ? grp nb:  0
#
# 339314 : Libye La situation sécuritaire au cœur d'une réunion du Conseil présidentiel grp nb:  0
#
# 339315 : Burkina Faso Au moins dix soldats tués dans l'attaque de camions de ravitaillement grp nb:  0
#
# 339316 : Sahara occidental L'arrêt de la Cour africaine, une preuve de l'échec de la politique marocaine grp nb:  0
#
# 339303 : Relizane Campagne de sensibilisation du secteur de la formation professionnelle grp nb:  0
#
# 339304 : Tourisme Plus de 6 millions d'estivants ont visité le littoral témouchentois grp nb:  0
#
# 339305 : Mostaganem Ouverture de la 2e édition du Salon international de l’agriculture grp nb:  0
#
# 339306 : AÏN-BEÏDA Arrestation de trois dealers grp nb:  0
#
# 339307 : CHECHAR (KHENCHELA) Plus de 400 lots de terrains à bâtir attribués grp nb:  0
#
# 339308 : Agriculture à Constantine Les pluies de l'espoir grp nb:  0
#
# 339298 : HB Chelghoum-Laïd Séparation consommée entre le Hilal et Rouabah grp nb:  0
#
# 339300 : MC Alger Arrivée différée de Benzarti grp nb:  0
#
# 339301 : Il doit rentrer aujourd’hui à Brest pour rompre son contrat Belaïli, le gâchis du siècle ! grp nb:  0
#
# 339302 :  Impact du développement du gaz de schiste sur les ressources en eau grp nb:  0
#
# 339299 : USF Constantine (inter-régions, groupe Est) Un nouveau promu aux dents longues grp nb:  0
#
# 339297 : BOXE / alors que les membres du BF réclament le départ du président de la FAB Le MJS enquête, Ferhat-Fazil dans de beaux draps ! grp nb:  0
#
# 339296 : Mourad Ferguene (ex-champion d'Afrique) : «L'Algérien est fait pour la boxe» grp nb:  0
#
# 339289 : Sommet arabe d’Alger : le président Tebboune invite officiellement le roi du Maroc grp nb:  0
#
# 339290 : Peut-on encore vivre sereinement en France en tant que musulman ? grp nb:  0
#
# 339280 :  Festival national du Malouf de Constantine : une ambiance apaisante lors de la 2ème soirée  grp nb:  0
#
# 339275 :  Foot (match amical) Algérie-Nigéria (2-1) : "Garder l’esprit de la gagne"  grp nb:  0
#
# 339276 :  Foot (amical) Algérie-Nigéria (2-1) : les "Verts" renversent les "Supers Eagles"  grp nb:  0
#
# 339270 :  Hémopathies : appel au renforcement des centres des maladies du sang  grp nb:  0
#
# 339271 :  Signature d'une convention-cadre entre le groupe ACS et Algerac  grp nb:  0
#
# 339272 :  Le SG de l'UNPA insiste sur l'impératif de protéger le foncier agricole  grp nb:  0
#
# 339273 :  Sonelgaz: le problème de recouvrement des créances entrave la réalisation des investissements programmés  grp nb:  0
#
# 339274 :  APN: Réunion de coordination sous la présidence de Boughali  grp nb:  0
#
# 339535 :  Hand/ Coupe d'Afrique des nations Dames 2022 (Tirage) : l'Algérie hérite du groupe A avec l'Angola  grp nb:  0
#
# 339534 :  Belani se félicite des bonnes conditions du déroulement du concours d'accès aux grades d'attachés et secrétaire des AE  grp nb:  0
#
# 339533 :  Foot (match amical) Sélection algérienne A’ : déclarations des joueurs avant d’affronter le Soudan  grp nb:  0
#
# 339532 :  ENTMV: une consultation internationale pour l'acquisition d'un nouveau système de réservation électronique  grp nb:  0
#
# 339531 :  Le ministre du tourisme et de l'artisanat s'entretient avec son homologue tunisien  grp nb:  0
#
# 339527 : Huile table : avec l’usine Cevital, l’Algérie va changer de statut grp nb:  0
#
# 339525 :
#             Sonatrach : Vers la révision du prix du gaz fourni à l’Espagne     grp nb:  0
#
# 339526 :  Ouverture jeudi à Alger du 21e Salon international du tourisme et des voyages  grp nb:  0
#
# 339524 :
#             Algérie-Nigeria 2-1 : les Verts reprennent confiance et affichent leurs ambitions     grp nb:  0
#
# 339521 :
# Un Colloque international lui est consacré Saint Augustin de retour à Souk Ahras
#  grp nb:  0
#
# 339522 :
# 14e Fibda à l'esplanade de Riadh El Feth Le Japon invité d'honneur
#  grp nb:  0
#
# 339523 :
# Organisé à Londres Festival algérien des arts et de la culture «Dz Fest»
#  grp nb:  0
#
# 339515 :
# Djamel Belmadi «C'est dans la difficulté qu'on progresse»
#  grp nb:  0
#
# 339516 :
# Les Verts avec le nouveau maillot
#  grp nb:  0
#
# 339517 :
# Équipe nationale A' Benbot et Khelif forfaits contre le Soudan
#  grp nb:  0
#
# 339518 :
# Ligue 2 - 2e journée Entre rachat et confirmation
#  grp nb:  0
#
# 339519 :
# Stade de Annaba Pose du tapis artificiel en fibres synthétiques
#  grp nb:  0
#
# 339520 :
# Manchester United Maguire, c'est désastreux
#  grp nb:  0
#
# 339508 :
# Le Koweït vote aujourd'hui 313 candidats aux élections législatives
#  grp nb:  0
#
# 339509 :
# Le Niger suspend le transit des produits pétroliers vers le Mali Tensions accrues au Sahel
#  grp nb:  0
#
# 339510 :
# Ciblant les forces d'occupation marocaines L'Armée sahraouie mène de nouvelles attaques à Mahbes, El-Bakari et Houza
#  grp nb:  0
#
# 339511 :
# Fuite de gaz dans les Nord Stream 1 et 2 Moscou juge «stupides» les soupçons occidentaux
#  grp nb:  0
#
# 339512 :
# Béjaïa 60 Cantines scolaires à l'arrêt
#  grp nb:  0
#
# 339513 :
# Explosion du prix du gaz à l'international Une aubaine pour les cimentiers
#  grp nb:  0
#
# 339514 :
# Fin du stage des Verts Du bon et du moins bon
#  grp nb:  0
#
# 339507 :
# Sous les balles des forces d'occupation sionistes à Jénine Quatre Palestiniens tombent en martyrs
#  grp nb:  0
#
# 339505 :
# Référendums au Donbass Les autorités pro russes revendiquent la victoire
#  grp nb:  0
#
# 339506 :
# Duel Lula - Bolsonaro au Brésil Les principaux candidats à la présidentielle
#  grp nb:  0
#
# 339502 :
# Revalorisation des salaires des enseignants Ce qu'en attendent les syndicats
#  grp nb:  0
#
# 339503 :
# L'UE finance un programme d'un million d'euros pour la Cour des comptes Comment bénéficier de l'expertise étrangère
#  grp nb:  0
#
# 339504 :
# Développement du partenariat public-privé En phase de concrétisation
#  grp nb:  0
#
# 339500 :
# Salon national de l'habitat, de l'immobilier et du décor Penser une maison intelligente
#  grp nb:  0
#
# 339501 :
# Oran Trois ateliers illégaux démantelés
#  grp nb:  0
#
# 339498 :
# Loi régissant les relations entre le Parlement et le gouvernement Des «lignes rouges» tracées
#  grp nb:  0
#
# 339499 :
# Tizi Ouzou 70 milliards pour le parc immobilier
#  grp nb:  0
#
# 339496 :
# Saïda Le wali active son autorité dans deux APC
#  grp nb:  0
#
# 339497 :
# Le mois d'octobre sera chargé en activités politiques et diplomatiques Alger retrouve son aura
#  grp nb:  0
#
# 339495 :
# L'Opep fête le 6ème anniversaire de l'accord historique d'Alger Un succès diplomatique éclatant!
#  grp nb:  0
#
# 339492 :
# Le ministre russe de l'agriculture l'a affirmé hier «Nos entreprises sont prêtes à investir en Algérie»
#  grp nb:  0
#
# 339493 :
# La république populaire de chine a 73 ans Un géant qui voit grand
#  grp nb:  0
#
# 339494 :
# Au terme d'âpres négociations menées avec l'Espagne et l'Italie Sonatrach relève les prix du gaz
#  grp nb:  0
#
# 339484 : Spéculation: Une importante quantité de l’huile de table saisie à Tébess grp nb:  0
#
# 339485 : Douanes: Saisie de plus de 16000 comprimés hallucinogènes grp nb:  0
#
# 339486 : Accidents de la circulation: 139 interventions effectuées par la Protection civile grp nb:  0
#
# 339487 : Affaires religieuses: Mawlid El Nabawi sera célébré le 08 octobre prochain grp nb:  0
#
# 339480 : Afin de faire connaître l’étendue du patrimoine culturel, le ministère de la Culture présent en force au SITEV  grp nb:  0
#
# 339481 : Covid-19: Huit nouvelles infections enregistrées grp nb:  0
#
# 339482 : Système pénitentiaire en Algérie: Zreb évoque le respect des droits de l’homme et la préservation de la dignité des détenus grp nb:  0
#
# 339483 : En vue d’éradiquer la rage d’ici 2030: Lancement d’un Plan national stratégique grp nb:  0
#
# 339479 : Théâtre, musique symphonique, inchad, BD… : 5 Festivals au programme du mois d’octobre grp nb:  0
#
# 339478 : Sonelgaz : «Les créances ont atteint 161 milliards DA», selon Mourad Adjal grp nb:  0
#
# 339477 : Dilmi : «Le foncier agricole est une ligne rouge à ne pas franchir» grp nb:  0
#
# 339475 : Sonatarch :Une augmentation de la consommation de gaz estimé entre 4 à 5 % par an grp nb:  0
#
# 339476 : Energies renouvelables: “«Mise en place d’une capacité de 15.000 MWe à l’horizon 2035» grp nb:  0
#
# 339474 : L’OPEP célèbre le 6éme anniversaire de l’Accord historique d’Alger grp nb:  0
#
# 339473 : Koli : «Les producteurs locaux ont gagné le pari de faire de la rentrée scolaire une réussite» grp nb:  0
#
# 339470 : Hakkar : «Ces accords ouvrent des horizons de partenariat solide avec l’Italie et l’Espagne» grp nb:  0
#
# 339471 : APN: Air Algérie augmentera le nombre de ses vols à partir d’octobre prochain grp nb:  0
#
# 339472 : Salon international des énergies renouvelables: la 12 ème édition du 24 au 26 octobre à Oran grp nb:  0
#
# 339469 : Boukhalfa Laala : «Il y a une volonté politique, mais le problème réside dans l’application des directives» grp nb:  0
#
# 339465 : Création d’une commission nationale de coordination et de suivi de l’innovation grp nb:  0
#
# 339466 : Boumerdès:  Près de 300 familles relogées grp nb:  0
#
# 339467 : Mostaganem : Le wali insiste sur l’investissement dans l’élevage des vaches laitières grp nb:  0
#
# 339468 : 1ere édition du CCUS à Oran : Pour une empreinte carbone nulle à l’horizon 2030 grp nb:  0
#
# 339464 : Hossam Zaki salue les efforts déployés par toutes les institutions étatiques algériennes pour la réussite du sommet arabe grp nb:  0
#
# 339462 : Suleiman Abdel Rahim, DG de l’ASBU:«Le Sommet arabe d’Alger connaît un niveau de préparation jamais atteint durant ces 20 dernières années» grp nb:  0
#
# 339463 : Les relations historiques profondes entre les deux pays évoquées grp nb:  0
#
# 339460 : Réunion du Gouvernement: Quatre secteurs à l’ordre du jour grp nb:  0
#
# 339461 : ANP: Mise en échec de l’introduction de plus 14 quintaux de kif traité via les frontières avec le Maroc grp nb:  0
#
# 339458 :
# Equipe d’Algérie : Belmadi veut 3 matchs amicaux en novembre grp nb:  0
#
# 339459 :
# Affaire Brest : Belmadi lance un conseil à Belaïli grp nb:  0
#
# 339456 :
# Turquie : Feghouli en litige avec Galatasaray grp nb:  0
#
# 339457 :
# Equipe d’Algérie : quand Belmadi compare Bennacer à Iniesta et Modric grp nb:  0
#
# 339455 :
# Gaz : Sonatrach signe de nouveaux accords avec l’italien ENEL grp nb:  0
#
# 339450 :
# Taux de change banque et marché noir : l’euro décroît ce 28 septembre grp nb:  0
#
# 339451 :
# Météo Algérie : alerte pluies et orages sur 6 wilayas ce 28 septembre grp nb:  0
#
# 339452 :
# France : quand un Algérien résiste à son expulsion à Marseille grp nb:  0
#
# 339453 :
# Hausse prix du gaz livré à l’Espagne : ce qu’a dit le PDG de Sonatach grp nb:  0
#
# 339454 :
# Coût de la vie : quel pouvoir d’achat pour les Algériens en 2022 ? grp nb:  0
#
# 339448 :
# Crime crapuleux à Relizane : un jeune égorgé dans une forêt grp nb:  0
#
# 339449 :
# Le lycée national des arts « Ali Maâchi » ouvre ses portes à Alger grp nb:  0
#
# 339447 :
# Logement AADL en Algérie : vers une nouvelle distribution grp nb:  0
#
# 339441 :
# Trafic de drogue au Jardin d’essai : 2 hommes et 1 femme écroués grp nb:  0
#
# 339442 :
# Prix articles scolaires : le ministère du Commerce explique la flambée grp nb:  0
#
# 339443 :
# Covid-19 en Algérie : légère hausse du nombre de cas ce 28 septembre grp nb:  0
#
# 339444 :
# Les prix de l’huile d’olive flambent en Algérie grp nb:  0
#
# 339446 :
# Crise Algérie – Espagne : quels sont les secteurs impactés ? grp nb:  0
#
# 339445 :
# France : un couple algérien se déchire pour un titre de séjour grp nb:  0
#
# 339440 :
# Anniversaire de la mort de cheb Hasni : un « big » événement au menu grp nb:  0
#
# 339436 : L’Algérien venu de Paris à pied fait une nouvelle apparition à l’approche d’Alger grp nb:  0
#
# 339437 : L’Espagne lance un appel à l’Algérie après les retombées de la crise sur son économie grp nb:  0
#
# 339438 :
# Chasse aux « parkingueurs » : la police fait une descente à Alger grp nb:  0
#
# 339439 :
# 4 secteurs au menu de la réunion du Gouvernement ce 28 septembre grp nb:  0
#
# 339431 : Record des Algériens Belloumi et Madjer : Mahrez s’approche doucement mais surement grp nb:  0
#
# 339432 : Maillot d’entraînement Adidas : des Marocains accusent l’Algérie de dérober leurs symboles grp nb:  0
#
# 339433 : Équipe d’Algérie : Belmadi évoque 2 matchs internationaux pour novembre grp nb:  0
#
# 339434 : « Bizarre que l’Algérie ne soit pas qualifiée au Mondial », estime Mustapha Al-Agha (vidéo) grp nb:  0
#
# 339435 : Invité au Sommet arabe d’Alger, le roi du Maroc, Mohammed VI, viendra-t-il ? grp nb:  0
#
# 339428 : L’Algérienne Amira Riaa s’explique sur le raisons de son déménagement à Dubaï grp nb:  0
#
# 339429 : Un supporter attaque avec les Verts contre le Nigeria : vidéo prise du meilleur angle de vue grp nb:  0
#
# 339430 : Télégramme : l’Algérien « Belaïli a massacré son appartement à Brest et a disparu à Paris » grp nb:  0
#
# 339427 : L’Algérienne Dalia Chih rend hommage à Idir dans un concert à Paris grp nb:  0
#
# 339417 : Algérie – Espagne : du nouveau pour le gaz grp nb:  0
#
# 339418 : Un Algérien de 70 ans termine le marathon de Berlin dans le même temps que le ballon d’Or Kaka grp nb:  0
#
# 339419 : Foot : avec un Belaili la tête ailleurs et un Atal en superforme, l’Algérie domine le Nigeria en amical grp nb:  0
#
# 339420 : Algérie : une mesure avantageant l’Italie au détriment de l’Espagne grp nb:  0
#
# 339421 : Automobile en Algérie : voici le nombre de voitures converties au GPL en 2022 grp nb:  0
#
# 339422 : Immobilier Algérie : du nouveau pour ce qui est des logements AADL grp nb:  0
#
# 339423 : AADL Algérie : une large opération de distribution à cette date grp nb:  0
#
# 339424 : Algérie : Ooredoo met en vente ses tours télécoms grp nb:  0
#
# 339425 : Ouedkniss auto : les offres de vente de voitures de ce 28 septembre 2022 grp nb:  0
#
# 339426 : Algérie : visite surprise du ministre de l’Habitat en pleine nuit au stade de Douera (vidéo) grp nb:  0
#
# 339416 : L’Algérie veut faire connaître sa production agricole -Vidéo grp nb:  0
#
# 339412 :  Sommet arabe: Stéphane Dujarric confirme la participation du SG de l'ONU  grp nb:  0
#
# 339413 :  Sonatrach : accord avec six partenaires sur la révision des prix du gaz exporté  grp nb:  0
#
# 339411 :  Algérie-Russie: intensifier les investissements communs et transférer la technologie  grp nb:  0
#
# 339410 : Gaz algérien : Les prix réajustés pour l’Italie et l’Espagne grp nb:  0
#
# 339406 :
# 21ème édition du Salon international du tourisme et des voyages (SITEV) Benabderrahmane donnera le coup de starter
#  grp nb:  0
#
# 339409 :  Prix du président de la République du journaliste professionnel: les membres du jury installés  grp nb:  0
#
# 339269 : Politique générale du gouvernement : Comment relancer l’économie nationale  via le code d’investissement et la bourse d’Alger ? grp nb:  0
#
# 339235 :
# Trêve au Yémen Al-Alimi et l’envoyé spécial de l’ONU discutent du renouvellement
#  grp nb:  0
#
# 339236 :
# Il annonce une récolte record en Russie de 150 millions de tonnes en 2022 Poutine critique des exportations ukrainiennes réservées à l’UE
#  grp nb:  0
#
# 339237 :
# À la tribune des Nations unies Le Premier ministre malien solde les comptes
#  grp nb:  0
#
# 339238 :
# La victoire de l'extrême droite plonge le pays dans une ère d'incertitudes Une partition italienne
#  grp nb:  0
#
# 339239 :
# Burkina Au moins une «dizaine de morts» dans une attaque terroriste
#  grp nb:  0
#
# 339240 :
# Stade Brestois Belaïli, c'est déjà fini!
#  grp nb:  0
#
# 339241 :
# JS Kabylie Amrani met la machine en branle
#  grp nb:  0
#
# 339242 :
# Activités physiques et sportives Le développement et les performances mis en relief
#  grp nb:  0
#
# 339243 :
# Coupe d'Algérie 2022-2023 La compétition fait son retour
#  grp nb:  0
#
# 339244 :
# Championnat d'Afrique de Triathlon L'Algérie décroche deux médailles
#  grp nb:  0
#
# 339245 :
# Real Madrid Perez pourra se faire plaisir au Mercato
#  grp nb:  0
#
# 339246 :
# Festival national du théâtre comique à Médéa Hommage à Sirat Boumediene
#  grp nb:  0
#
# 339247 :
# Commémoration du décès de cheb Hasni La pièce «Hasni chante ce jeudi» bientôt présentée
#  grp nb:  0
#
# 339248 :
# Institut français d'Alger Spectacle de danse contemporaine
#  grp nb:  0
#
# 339249 :
# Il se tiendra le 4 octobre Un colloque international sur le théâtre amazigh
#  grp nb:  0
#
# 339250 :
# Conférence à Tlemcen Promotion du tourisme et la protection du legs culturel
#  grp nb:  0
#
# 339251 :
# Radiothérapie stéréotaxique La nouvelle acquisition du CHU d'Annaba
#  grp nb:  0
#
# 339252 : Algérie – Nigéria : belle victoire pour les hommes de Belmadi grp nb:  0
#
# 339253 :
#             Algérie-Nigeria : un match amical à caractère officiel     grp nb:  0
#
# 339254 : Stade Brestois/Le match contre les Parisiens pourrait précipiter le départ du Dz de la Bretagne : Belaïli, l’indigeste Paris-Brest grp nb:  0
#
# 339255 : La sélection ne se porte pas bien à quelques semaines de la Coupe du monde 2022 : Le doute grandit pour le Qatar ! grp nb:  0
#
# 339256 : JO-2024/Avant de débloquer l’enveloppe de 4 milliards pour les athlètes qualifiés / Fédérations : les Autorités prévoient un sacré coup de balai ! grp nb:  0
#
# 339257 : Sur son refus du vaccin / Irving : « J’ai renoncé a 100 et quelques millions en maintenant ma décision » grp nb:  0
#
# 339258 : Tennis : Cet indice sur les intentions de Nadal pour la fin de saison grp nb:  0
#
# 339259 : Tennis : quand Djokovic recadre un journaliste sur Nadal grp nb:  0
#
# 339260 : Le chant traditionnel authentique ravive la scène artistique : Cirta retrouve son festival du Malouf grp nb:  0
#
# 339261 : Projet de loi de l’artiste : Plaidoyer pour la création de marchés de l’art grp nb:  0
#
# 339262 : Espagne ! La guerre fiscale est lancée à un an des élections grp nb:  0
#
# 339263 : Italie ,: Délicates tractations de Meloni pour former son gouvernement grp nb:  0
#
# 339264 : Après la victoire de Meloni en Italie : Vers un axe Italie-Hongrie-Pologne au sein de l’UE grp nb:  0
#
# 339265 : Organisation à Londres du Festival algérien des arts et de la culture «Dz Fest» grp nb:  0
#
# 339266 : Coup d’envoi dans la soirée de lundi à Mostaganem de la 53e édition : Le Festival culturel national du théâtre amateur retrouve les planches grp nb:  0
#
# 339267 : Avec 10,5 millions d’estivants nationaux et étrangers et 200 milliards de DA de chiffre d’affaires : Le Tourisme reprend des couleurs grp nb:  0
#
# 339268 : Finances locales et aménagement du territoire : Quid des marges de manœuvre de la nouvelle approche ? grp nb:  0
#
# 339403 :  Médias en temps de Guerre: le Forum de la Mémoire salue le rôle pionnier de feu M'hamed Yazid  grp nb:  0
#
# 339404 :  Le président du CNESE examine avec les présidents de groupes parlementaires les moyens de coopération avec le Parlement  grp nb:  0
#
# 339402 :  Le Gouvernement examine un avant-projet de loi relatif à la protection du droit syndical  grp nb:  0
#
# 339401 :  Stratégie nationale de développement des statistiques: un impératif pour être au diapason des changements nationaux et internationaux  grp nb:  0
#
# 339400 :  Gaz naturel: Sonatrach et ENEL signent des accords pour l'ajustement des prix  grp nb:  0
#
# 339399 :  Le Premier ministre inaugurera jeudi le 21e SITEV  grp nb:  0
#
# 339397 :  Etablissements publics de santé: les équipes d'inspection entament leurs visites  grp nb:  0
#
# 339394 : La rage continue de tuer en Algérie grp nb:  0
#
# 339396 :  Air Algérie: le nombre de vols atteindra 78% des niveaux d'avant Covid-19  grp nb:  0
#
# 339389 :  Sommet arabe: émission d'un timbre-poste arabe unifié 2022  grp nb:  0
#
# 339390 :  L'AAST disposée à contribuer au développement national  grp nb:  0
#
# 339382 :  Arrivée à Alger de la dépouille de la journaliste et moudjahida Zineb El Mili  grp nb:  0
#
# 339383 :  De Bandung à l'ONU.. Quand la "question algérienne" prenait une dimension internationale  grp nb:  0
#
# 339384 :  Ligue 2 amateur : confirmer les bons débuts pour certains, se ressaisir pour d'autres  grp nb:  0
#
# 339385 :
# Dans le cadre des préparatifs du Sommet arabe d'Alger Lamamra reçoit le SG adjoint de la Ligue arabe
#  grp nb:  0
#
# 339388 :  Finance islamique: la BA signe un contrat d'assistance technique  grp nb:  0
#
# 339374 :  La Chine attache une grande importance au développement des relations avec l'Algérie  grp nb:  0
#
# 339375 :  Lamamra reçoit le SG adjoint de la Ligue arabe  grp nb:  0
#
# 339376 :  Mostaganem: des solutions innovantes pour réduire les effets du changement climatique  grp nb:  0
#
# 339377 : Pourquoi l’Espagne ne veut-elle pas résoudre le problème du Sahara Occidental ? grp nb:  0
